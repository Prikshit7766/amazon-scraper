# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import re

# %%
# Function to extract Product Title
def get_title(soup):

    try:
        # Outer Tag Object
        title = soup.find("span", attrs={"id":'productTitle'})
        
        # Inner NavigatableString Object
        title_value = title.text

        # Title as a string value
        title_string = title_value.strip()

    except AttributeError:
        title_string = ""

    return title_string

# Function to extract Product Price
def get_price(soup):

    try:
        
        price = soup.find("span", attrs={"class":'a-price aok-align-center'}).find("span", attrs={"class": "a-price-whole"}).get_text()[:-1]

    except AttributeError:

        try:
            # If there is some deal price
            price = soup.find("span", attrs={'id':'priceblock_dealprice'}).string.strip()

        except:
            price = ""

    return price

# Function to extract Product Rating
def get_rating(soup):

    try:
        rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()
    
    except AttributeError:
        try:
            rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
        except:
            rating = ""

    return rating

# Function to extract Number of User Reviews
def get_review_count(soup):
    try:
        review_count = soup.find("span", attrs={'id':'acrCustomerReviewText'}).string.strip()

    except AttributeError:
        review_count = ""

    return review_count

# Function to extract Availability Status
def get_availability(soup):
    try:
        available = soup.find("div", attrs={'id':'availability'})
        available = available.find("span").string.strip()

    except AttributeError:
        available = "Not Available"

    return available

def get_asin(href,soup):
    try:
        asin = re.search(r'/[dg]p/([^/]+)', href, flags=re.IGNORECASE)
        if asin:
            asin_number=asin.group(1)
        if asin==None:
                s=soup.find("div", attrs={"id":'detailBullets_feature_div'}).ul.text
                L=s.split()
                for i in range(len(L)):
                    if len(L[i])==10:
                        if L[i].isupper()==True:
                            asin_number=L[i]
                            break

                return asin_number  
        else:
            return asin_number           
    except AttributeError:
            asin_number=""
            return asin_number
            
def get_product_description(soup):
    try:
        product_description=soup.find("div", attrs={"id":'feature-bullets'}).text.strip().split("   ")
    except AttributeError:
            product_description=""
    return product_description
    
    
def get_seller(soup):
    try:
        #seller=soup.find("div", attrs={"id":'merchant-info'}).find(attrs={"id":"sellerProfileTriggerId"}).text
        seller=soup.find("div", attrs={"id":'merchant-info'}).text[9:-28]
        return seller
    except AttributeError: 
        seller=""
        return seller
    
    
def get_manufacturer(soup):
    try:
        manufacturer=soup.find("table", attrs={"id":'productDetails_detailBullets_sections1'}).find_all(attrs={"class":'a-size-base prodDetAttrValue'})[2].text
        return manufacturer
    
    except AttributeError:
        try:
            a=len(soup.find("div", attrs={"id":'detailBulletsWrapper_feature_div'}).find_all("span"))
            correct='Manufacturer'
            for i in range(a):
                w=new_soup.find("div", attrs={"id":'detailBulletsWrapper_feature_div'}).find_all("span")[i].text.replace("                                    ","")[:12]
                if w==correct:
                    manufacturer=new_soup.find("div", attrs={"id":'detailBulletsWrapper_feature_div'}).find_all("span")[i+1].text
                    break
            return manufacturer
        except:
            manufacturer = ""
            return manufacturer

# %% [markdown]
# ## for main page

# %%
if __name__ == '__main__':

    # add your user agent 
    # Headers for request
    HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36', 'Accept-Language': 'en-INR, en;q=0.5'}) 

    # The webpage URL
    amazon_url="https://www.amazon.in/s?k=bags&crid=2M096C61O4MLT&qid=1653308124&sprefix=ba%2Caps%2C283&ref=sr_pg_1"

    # HTTP Request
    webpage = requests.get(amazon_url, headers=HEADERS)

    # Soup Object containing all data
    soup = BeautifulSoup(webpage.content, "html.parser")

    # Fetch links as List of Tag Objects
    links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})

    # Store the links
    links_list = []

    # Loop for extracting links from Tag Objects
    for link in links:
            links_list.append(link.get('href'))

    d = {"Product URL":[],"Product Name":[], "Product Price":[], "Rating":[], "Number of reviews":[],"Availability":[],"ASIN":[],"Product Description":[],"Sold by":[],"Manufacturer":[]}
    
    # Loop for extracting product details from each link 
    for link in links_list:
        new_webpage = requests.get("https://www.amazon.in" + link, headers=HEADERS)

        new_soup = BeautifulSoup(new_webpage.content, "html.parser")

        # Function calls to display all necessary product information
        d["Product URL"].append("https://www.amazon.in"+link)
        d['Product Name'].append(get_title(new_soup))
        d['Product Price'].append(get_price(new_soup))
        d['Rating'].append(get_rating(new_soup))
        d['Number of reviews'].append(get_review_count(new_soup))
        d['Availability'].append(get_availability(new_soup))
        d['ASIN'].append(get_asin("https://www.amazon.in" + link,new_soup))
        d['Product Description'].append(get_product_description(new_soup))
        d['Sold by'].append(get_seller(new_soup))
        d['Manufacturer'].append(get_manufacturer(new_soup))
        
        


    
    amazon_df = pd.DataFrame.from_dict(d)
    amazon_df['Product Name'].replace('', np.nan, inplace=True)
    amazon_df = amazon_df.dropna(subset=['Product Name'])
    amazon_df.to_csv("amazon_data.csv", header=True, index=False)

# %%
amazon_df
# Out:
#                                           Product URL  \
# 0   https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 1   https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 2   https://www.amazon.in/American-Tourister-AMT-S...
# 3   https://www.amazon.in/Wesley-Milestone-Waterpr...
# 4   https://www.amazon.in/Skybags-Brat-Black-Casua...
# 5   https://www.amazon.in/ADISA-Laptop-Backpack-Of...
# 6   https://www.amazon.in/Safari-Backpack-Resistan...
# 7   https://www.amazon.in/Wesley-Milestone-Waterpr...
# 8   https://www.amazon.in/Wesley-Spartan-Hiking-Ra...
# 9   https://www.amazon.in/FUR-JADEN-Leatherette-Po...
# 10  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 11  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 12  https://www.amazon.in/Backpack-Small-Black-Wat...
# 13  https://www.amazon.in/Kuber-Industries-Handcra...
# 14  https://www.amazon.in/Fiesto-Fashion-Womens-Ha...
# 15  https://www.amazon.in/ADISA-women-girls-black-...
# 16  https://www.amazon.in/Lapis-Lupo-Flower-Embroi...
# 17  https://www.amazon.in/Blue-Tree-Backpack-Carto...
# 18  https://www.amazon.in/School-Backpack-Cartoon-...
# 19  https://www.amazon.in/Blue-Tree-Velvet-Spiderm...
# 20  https://www.amazon.in/MosQuick%C2%AE-Drawstrin...
# 21  https://www.amazon.in/Amazon-Brand-Solimo-so_f...
# 22  https://www.amazon.in/Backpack-Toddler-Animal-...
# 23  https://www.amazon.in/Backpack-Toddler-Animal-...
# 24  https://www.amazon.in/Blue-Tree-Synthetic-Cart...
# 25  https://www.amazon.in/TRUE-HUMAN-Anti-Theft-ba...
# 26  https://www.amazon.in/ADISA-BP005-Weight-Casua...
# 27  https://www.amazon.in/Skybags-Polypropylene-Cm...
# 28  https://www.amazon.in/Half-Moon-Backpack-Lugga...
# 29  https://www.amazon.in/Northzone-Waterproof-Bac...
# 30  https://www.amazon.in/AirCase-C34-Laptop-Backp...
# 31  https://www.amazon.in/Bennett-Mystic-Shoulder-...
# 32  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 33  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
#
#                                          Product Name Product Price  \
# 0                             Anti Theft Faux Leather           499
# 1   URBAN TRIBE Havana 15.6" inch Laptop Backpack ...           998
# 2   American Tourister 32 Ltrs Black Casual Backpa...         1,299
# 3   Wesley Milestone 2.0 Casual Waterproof Laptop ...           565
# 4           Skybags Brat Black 46 Cms Casual Backpack           669
# 5   ADISA 15.6 inch Laptop Backpack Office Bag Col...           499
# 6   Safari Flash Casual Backpack, 26 ltr Water Res...           699
# 7   Wesley Unisex Milestone Casual Waterproof Lapt...           498
# 8   Wesley Spartan Unisex Travel Hiking Laptop Bag...           798
# 9   Fur Jaden Brown Textured Leatherette Stylish &...           889
# 10  Chris & Kate 42ltr Navy-Red Comfortable Casual...           549
# 11  HEROZ Hammer Unisex Nylon 45 L Travel Laptop B...         1,424
# 12  Mi Step Out 12 L Mini Backpack (Small Size, Bl...           349
# 13  Kuber Industries Women's Handkerchief Set (Cream)           312
# 14  Fiesto Fashion PU Leather Handbags With Sling ...           615
# 15              ADISA women girls embroided sling bag           495
# 16  Lapis O Lupo Women Vegan Leather Handbags Flow...         1,039
# 17  Blue Tree Kids School Bag Soft Plush Backpack ...           448
# 18  Blue Tree Kids School Bag Soft Plush Backpack ...           448
# 19            Blue Tree 10 LTR Velvet School Backpack           339
# 20  MosQuick® Clear large Drawstring Bags Clear Pl...           399
# 21  Amazon Brand - Solimo Polyester Duffel Gym Bag...           549
# 22  blue tree 10 ltrs (5 Cms)Backpack(Rider01_Yellow)           298
# 23  blue tree 15 ltrs (38 Cms) backpack(INVALID DA...           278
# 24  blue tree 10 ltrs (35 Cms) backpack(VS-Items-3...           299
# 25  TRUE HUMAN® Emperor Anti-Theft backpack With U...           699
# 26         ADISA Light Weight Laptop Backpack 32 Ltrs           499
# 27  Skybags Polypropylene 46 Cms Travel Bag(DFACN1...           658
# 28  Half Moon Large 37L Laptop Bag Backpack for me...           849
# 29  Northzone Casual Waterproof Laptop Backpack/Of...           510
# 30  AirCase Laptop Bag Backpack Case Pouch for Lap...           999
# 31  Bennett™ Mystic Formal Business Briefcase Bag ...           512
# 32  LOOKMUSTER (15.6 inch 30 L Casual Waterproof L...           599
# 33  Wenger 17.5" ScanSmart Laptop Backpack, 30 Lit...
#
#                 Rating Number of reviews Availability        ASIN  \
# 0   3.9 out of 5 stars        51 ratings    In stock.  B08WLS5XBP
# 1   3.9 out of 5 stars       684 ratings    In stock.  B01LXNNFDF
# 2   4.1 out of 5 stars    51,370 ratings    In stock.  B07CJCGM1M
# 3   4.3 out of 5 stars     9,226 ratings    In stock.  B084JGJ8PF
# 4   4.1 out of 5 stars     3,368 ratings    In stock.  B08Z1HHHTD
# 5   3.9 out of 5 stars       462 ratings    In stock.  B09TPX22NF
# 6   3.9 out of 5 stars     2,184 ratings    In stock.  B09B29F66W
# 7   4.3 out of 5 stars    12,103 ratings    In stock.  B07K8KLB3P
# 8   4.1 out of 5 stars       912 ratings    In stock.  B098QFF5TJ
# 9   4.3 out of 5 stars     5,318 ratings    In stock.  B07M9BRCQ5
# 10       Previous page                      In stock.  B0BKWF2Q38
# 11  4.3 out of 5 stars     7,643 ratings    In stock.
# 12  4.1 out of 5 stars     7,630 ratings    In stock.  B088XB5XY8
# 13  3.8 out of 5 stars       472 ratings    In stock.  B082VDVJGM
# 14  3.9 out of 5 stars     4,073 ratings    In stock.  B082Z33ZDS
# 15  4.2 out of 5 stars     1,412 ratings    In stock.  B08RWBP3H2
# 16  4.2 out of 5 stars     3,600 ratings    In stock.  B07RXYSJHF
# 17  4.2 out of 5 stars         7 ratings    In stock.  B097NH6X4C
# 18  4.0 out of 5 stars         4 ratings    In stock.  B08WWG91Q3
# 19  4.0 out of 5 stars     1,044 ratings    In stock.  B07HLYW3FF
# 20  4.3 out of 5 stars        46 ratings    In stock.  B09SB5DP5Y
# 21  4.3 out of 5 stars        92 ratings    In stock.  B084DQ182R
# 22  4.0 out of 5 stars        61 ratings    In stock.  B09H3H3898
# 23  4.0 out of 5 stars       218 ratings    In stock.  B089WFG3BK
# 24  4.0 out of 5 stars       663 ratings    In stock.  B07CXXYQ5X
# 25  3.7 out of 5 stars     1,702 ratings    In stock.  B09QJ7ZF2Y
# 26  4.0 out of 5 stars     5,547 ratings    In stock.  B07F3X45WZ
# 27  4.0 out of 5 stars        23 ratings    In stock.  B0B6CH21F9
# 28  3.9 out of 5 stars     2,126 ratings    In stock.  B09VCLZ3K4
# 29  5.0 out of 5 stars         2 ratings    In stock.  B0BS6QQZYN
# 30  3.9 out of 5 stars       710 ratings    In stock.  B07QN4KXWG
# 31  4.1 out of 5 stars     4,860 ratings    In stock.  B08X2T2M8G
# 32  3.4 out of 5 stars         3 ratings    In stock.  INDUSTRIES
# 33  4.0 out of 5 stars        21 ratings    In stock.  B09V1GJ7D6
#
#                                   Product Description  \
# 0   [Anti-Theft backpack has added safety features...
# 1   [Laptop Compatibility: Yes, Laptop size: 15.6 ...
# 2   [Laptop Compatibility: No, Strap Type: Adjusta...
# 3   [30L Capacity: The Backpack has a padded lapto...
# 4   [Combination of functional & safety features i...
# 5   [Material: Water Resistant Light-Weight Polyes...
# 6   [HIGH QUALITY FABRIC: Our lightweight yet dura...
# 7   [Pattern Type : Pure Color || Closure Type : Z...
# 8             [Laptop bag fits upto 17.3 inch laptop]
# 9   [MATERIAL - We use Highest Quality of Artifici...
# 10  [Fit Type: Regular,  MATERIAL: Polyester, Stur...
# 11  [Material: Nylon, Inner Material: Polyester, C...
# 12  [Made of multi-coated 600D polyester Material ...
# 13  [PACKAGE CONTAIN: 1 Piece Embroidered Party We...
# 14  [Material: Leather,  Closure Type: Zip,  Strap...
# 15  [Material: PU / Synthetic Leather,  Closure: Z...
# 16  [Inner Material: Polyester; Color: Grey; Packa...
# 17  [About this item,  ☆DIMENSION:15x3.5x12inch/38...
# 18  [DIMENSION: 15 X 3.5 X 12 Inches / 38 X 8 X 30...
# 19  [Non-Toxic And Soft Fabric good quality and Wa...
# 20  [About this item,  MULTIPLE USAGE: Drawstring ...
# 21  [Made of 100% polyester water repellant fabric...
# 22  [?DIMENSION:15x3.5x12inch/38x8x30cm(WxDxH).Wei...
# 23  [?DIMENSION:15x3.5x12inch/38x8x30cm(WxDxH).Wei...
# 24  [Amazingly cute Super soft: Made of soft plush...
# 25  [Superior & Durability: Made of durable and Ec...
# 26  [Adjustable Shoulder Handles / Two Bottle hold...
# 27  [Spacious Main compartment,  Soft Grip handles...
# 28  [SPACIOUS AND LIGHTWEIGHT: Light weight and sp...
# 29  [Care Instructions: Machine Wash,  Sleek, Styl...
# 30  [Innovative Design: AirCase Laptop Backpack is...
# 31  [PREMIUM QUALITY MATERIAL: This laptop compute...
# 32  [Care Instructions: Hand Wash Only,  SPACIOUS ...
# 33  [FUNCTIONALITY WITH STYLE: The Wenger 17.5" Sc...
#
#                                               Sold by  \
# 0                Sold by FAST FASHION BAGS and Delive
# 1                               BackpackInternational
# 2                                    RetailEZ Pvt Ltd
# 3                          Appario Retail Private Ltd
# 4                                    RetailEZ Pvt Ltd
# 5                          Appario Retail Private Ltd
# 6                                    RetailEZ Pvt Ltd
# 7                          Appario Retail Private Ltd
# 8                          Appario Retail Private Ltd
# 9                                    RetailEZ Pvt Ltd
# 10                                     Chris and Kate
# 11                                     A. H. Creation
# 12                         Appario Retail Private Ltd
# 13                                      ETrade Online
# 14                  Sold by Fiesto fashion and Delive
# 15                                ADISA International
# 16                                   COALESCENT INDIA
# 17                                    Vancouver Store
# 18                                    Vancouver Store
# 19                                    Vancouver Store
# 20                                           MosQuick
# 21                                   RetailEZ Pvt Ltd
# 22                                    Vancouver Store
# 23                                    Vancouver Store
# 24                                    Vancouver Store
# 25                                  Rama luxury store
# 26                         Appario Retail Private Ltd
# 27                                   RetailEZ Pvt Ltd
# 28                                          Half_Moon
# 29                                      SB NTERPRISES
# 30                         Appario Retail Private Ltd
# 31                         Appario Retail Private Ltd
# 32          Sold by ABU GROUP OF INDUSTRIES and De...
# 33                                   RetailEZ Pvt Ltd
#
#                                          Manufacturer
# 0   WE MANUFACTURE ALL KINDS OF BAGS FOR MORE DETA...
# 1                      Backpack International Pvt Ltd
# 2                                          Samsonite
# 3    Longani Trading Company, F-82, Sector-1, Bawa...
# 4                                  VIP Industries Ltd
# 5                                               ADISA
# 6                                   Safari Industries
# 7    Longani Trading Company, F-82, Sector-1, Bawa...
# 8                                              Wesley
# 9                                           Fur Jaden
# 10
# 11                       13.2 x 9.2 x 21 Centimeters
# 12   Xiaomi Technology India Private Limited, Buil...
# 13   Kuber Industries, Kuber Industries,G-185, Ban...
# 14                                     Fiesto Fashion
# 15                                              ADISA
# 16                                   Coalescent India
# 17     Vancouver Store, Vancouver.store013@gmail.com
# 18                                         Blue Tree
# 19                                          Blue Tree
# 20
# 21   Flab International Pvt. Ltd., Flab Internatio...
# 22                                    Vancouver Store
# 23                                    Vancouver Store
# 24                                    Vancouver Store
# 25
# 26                                              ADISA
# 27  VIP Industries Ltd. DGP House, 5th Floor, 88C ...
# 28                                       Amazing Bags
# 29                                         SHABA BAGS
# 30                                            AirCase
# 31                   Texcoco Enterprises, 9958166528
# 32                            ABU GROUP OF INDUSTRIES
# 33                                         Victorinox

# %% [markdown]
# # for multiple pages

# %%
if __name__ == '__main__':

    # add your user agent 
    # Headers for request
    HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36', 'Accept-Language': 'en-INR, en;q=0.5'}) 

    # The webpage URL
    amazon_url="https://www.amazon.in/s?k=bags&crid=2M096C61O4MLT&qid=1653308124&sprefix=ba%2Caps%2C283&ref=sr_pg_1"

    # HTTP Request
    webpage = requests.get(amazon_url, headers=HEADERS)

    # Soup Object containing all data
    soup = BeautifulSoup(webpage.content, "html.parser")

    # Fetch links as List of Tag Objects
    links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})

    # Store the links
    links_list = []

    # Loop for extracting links from Tag Objects
    for link in links:
            links_list.append(link.get('href'))

    d = {"Product URL":[],"Product Name":[], "Product Price":[], "Rating":[], "Number of reviews":[],"Availability":[],"ASIN":[],"Product Description":[],"Sold by":[],"Manufacturer":[]}
    
    # Loop for extracting product details from each link 
    for link in links_list:
        new_webpage = requests.get("https://www.amazon.in" + link, headers=HEADERS)

        new_soup = BeautifulSoup(new_webpage.content, "html.parser")

        # Function calls to display all necessary product information
        d["Product URL"].append("https://www.amazon.in"+link)
        d['Product Name'].append(get_title(new_soup))
        d['Product Price'].append(get_price(new_soup))
        d['Rating'].append(get_rating(new_soup))
        d['Number of reviews'].append(get_review_count(new_soup))
        d['Availability'].append(get_availability(new_soup))
        d['ASIN'].append(get_asin("https://www.amazon.in" + link,new_soup))
        d['Product Description'].append(get_product_description(new_soup))
        d['Sold by'].append(get_seller(new_soup))
        d['Manufacturer'].append(get_manufacturer(new_soup))
    
        
    for i in range(0,3):
        if i == 0:
            second_page_url="https://amazon.in" + soup.find_all("a", attrs={'class':'s-pagination-item s-pagination-button'})[0].get("href")
            webpage = requests.get(second_page_url, headers=HEADERS)
            soup=BeautifulSoup(webpage.content,"html.parser")
            # Fetch links as List of Tag Objects
            links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})

            # Store the links
            links_list = []

            # Loop for extracting links from Tag Objects
            for link in links:
                links_list.append(link.get('href')) 
            for link in links_list:
                new_webpage = requests.get("https://www.amazon.in" + link, headers=HEADERS)

                new_soup = BeautifulSoup(new_webpage.content, "html.parser")

                # Function calls to display all necessary product information
                d["Product URL"].append("https://www.amazon.in"+link)
                d['Product Name'].append(get_title(new_soup))
                d['Product Price'].append(get_price(new_soup))
                d['Rating'].append(get_rating(new_soup))
                d['Number of reviews'].append(get_review_count(new_soup))
                d['Availability'].append(get_availability(new_soup))
                d['ASIN'].append(get_asin("https://www.amazon.in" + link,new_soup))
                d['Product Description'].append(get_product_description(new_soup))
                d['Sold by'].append(get_seller(new_soup))
                d['Manufacturer'].append(get_manufacturer(new_soup))
            
        else :
            next_page_url="https://amazon.in" + soup.find_all("a", attrs={'class':'s-pagination-item s-pagination-button'})[-1].get("href")
            webpage = requests.get(next_page_url, headers=HEADERS)
            soup=BeautifulSoup(webpage.content,"html.parser")
 
            links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})

            # Store the links
            links_list = []

            # Loop for extracting links from Tag Objects
            for link in links:
                links_list.append(link.get('href')) 
            for link in links_list:
                new_webpage = requests.get("https://www.amazon.in" + link, headers=HEADERS)

                new_soup = BeautifulSoup(new_webpage.content, "html.parser")

                # Function calls to display all necessary product information
                d["Product URL"].append("https://www.amazon.in"+link)
                d['Product Name'].append(get_title(new_soup))
                d['Product Price'].append(get_price(new_soup))
                d['Rating'].append(get_rating(new_soup))
                d['Number of reviews'].append(get_review_count(new_soup))
                d['Availability'].append(get_availability(new_soup))
                d['ASIN'].append(get_asin("https://www.amazon.in" + link,new_soup))
                d['Product Description'].append(get_product_description(new_soup))
                d['Sold by'].append(get_seller(new_soup))
                d['Manufacturer'].append(get_manufacturer(new_soup))

    
    amazon_df = pd.DataFrame.from_dict(d)
    amazon_df['Product Name'].replace('', np.nan, inplace=True)
    amazon_df = amazon_df.dropna(subset=['Product Name'])
    amazon_df.to_csv("amazon_data.csv", header=True, index=False)

# %%
amazon_df
# Out:
#                                           Product URL  \
# 0   https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 1   https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 2   https://www.amazon.in/American-Tourister-AMT-S...
# 3   https://www.amazon.in/Wesley-Milestone-Waterpr...
# 4   https://www.amazon.in/ADISA-Laptop-Backpack-Of...
# ..                                                ...
# 95  https://www.amazon.in/HP-Lightweight-300-Grey-...
# 96  https://www.amazon.in/Nivia-6853BKGR-Polyester...
# 97  https://www.amazon.in/Classic-Leather-Laptop-B...
# 98  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 99  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
#
#                                          Product Name Product Price  \
# 0   URBAN TRIBE Havana 15.6" inch Laptop Backpack ...           998
# 1   Urban Tribe Jumbo Backpack with 17.3 inch Gami...         1,498
# 2   American Tourister 32 Ltrs Black Casual Backpa...         1,299
# 3   Wesley Milestone 2.0 Casual Waterproof Laptop ...           565
# 4   ADISA 15.6 inch Laptop Backpack Office Bag Col...           499
# ..                                                ...           ...
# 95  HP Lightweight 300 Grey Laptops Backpack with ...         1,002
# 96  NIVIA Basic Duffle Polyester Bag/ Gym Bags/ Ad...           245
# 97  Gear Classic 20L Faux Leather Water Resistant ...           999
# 98  COSMUS Madison waterproof Multipurpose Backpac...         1,196
# 99  TYPIFY® Polyester College Preppy Style Backpac...           999
#
#                 Rating Number of reviews Availability        ASIN  \
# 0   3.9 out of 5 stars       684 ratings    In stock.  B01LXNNFDF
# 1   4.1 out of 5 stars       198 ratings    In stock.  B01MSRADRY
# 2   4.1 out of 5 stars    51,370 ratings    In stock.  B07CJCGM1M
# 3   4.3 out of 5 stars     9,226 ratings    In stock.  B084JGJ8PF
# 4   3.9 out of 5 stars       462 ratings    In stock.  B09TPX22NF
# ..                 ...               ...          ...         ...
# 95  4.1 out of 5 stars        67 ratings    In stock.  B08CY44PVD
# 96  3.9 out of 5 stars       329 ratings    In stock.  B07NLB6FRS
# 97  4.4 out of 5 stars     2,268 ratings    In stock.  B07G4CYC74
# 98  4.2 out of 5 stars     2,166 ratings    In stock.  B078JVT384
# 99  5.0 out of 5 stars         7 ratings    In stock.  B0BNBTNWHS
#
#                                   Product Description  \
# 0   [Laptop Compatibility: Yes, Laptop size: 15.6 ...
# 1   [Separate 17.3 inch Laptop compartments for be...
# 2   [Laptop Compatibility: No, Strap Type: Adjusta...
# 3   [30L Capacity: The Backpack has a padded lapto...
# 4   [Material: Water Resistant Light-Weight Polyes...
# ..                                                ...
# 95  [Protect your precious 15.6-inch laptop with t...
# 96  [Strong stitching at major stress points provi...
# 97  [Outer material: synthetic, color: tan; Waterp...
# 98  [Care Instructions: Hand Wash Only,  Large mul...
# 99  [Perfection: A perfect pick for daily use, thi...
#
#                        Sold by  \
# 0        BackpackInternational
# 1        BackpackInternational
# 2             RetailEZ Pvt Ltd
# 3   Appario Retail Private Ltd
# 4   Appario Retail Private Ltd
# ..                         ...
# 95  Appario Retail Private Ltd
# 96            RetailEZ Pvt Ltd
# 97            RetailEZ Pvt Ltd
# 98  COSMUS LIFESTYLE PVT. LTD.
# 99        Tiyasha Trading Corp
#
#                                          Manufacturer
# 0                      Backpack International Pvt Ltd
# 1                     BACKPACK INTERNATIONAL PVT LTD.
# 2                                          Samsonite
# 3    Longani Trading Company, F-82, Sector-1, Bawa...
# 4                                               ADISA
# ..                                                ...
# 95                            Korrun India Pvt. Ltd.
# 96   Nivia, Freewill Sports Pvt Ltd. - 391 Leather...
# 97                           Gear Merchandise PVT LTD
# 98                                             Cosmus
# 99
#
# [100 rows x 10 columns]

# %% [markdown]
# - some of the functions I hard coded to get the desire result
